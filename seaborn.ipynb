# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.plot(df['petal_length'],df['sepal_length'])

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.plot(kind='scatter',
       x='petal_length',sns
       y='sepal_length')
plt.show()

# %%
df.plot(kind='scatter',
       x='petal_length',
       y='sepal_length')
plt.grid()

# %%
df.value_counts()
# Out:
# sepal_length  sepal_width  petal_length  petal_width  species
# 5.8           2.7          5.1           1.9          virginica     2
# 6.2           2.2          4.5           1.5          versicolor    1
#               2.9          4.3           1.3          versicolor    1
#               3.4          5.4           2.3          virginica     1
# 6.3           2.3          4.4           1.3          versicolor    1
#                                                                    ..
# 5.4           3.9          1.3           0.4          setosa        1
#                            1.7           0.4          setosa        1
# 5.5           2.3          4.0           1.3          versicolor    1
#               2.4          3.7           1.0          versicolor    1
# 7.9           3.8          6.4           2.0          virginica     1
# Length: 149, dtype: int64

# %%
df['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sns.set(style='darkgrid') #whitegrid
sns.scatterplot(x='sepal_length',y='petal_length',data=df)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.set(style='darkgrid') #whitegrid
sns.scatterplot(x='sepal_length',y='petal_length',hue='species',data=df)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.FacetGrid(df, hue='species',height=6).map(plt.scatter,
                                              'sepal_length',
                                              'petal_length').add_legend()

# %%
df = pd.read_csv('census_data.csv')
df
# Out:
#        age          workclass    education  education_num  \
# 0       39          State-gov    Bachelors             13
# 1       50   Self-emp-not-inc    Bachelors             13
# 2       38            Private      HS-grad              9
# 3       53            Private         11th              7
# 4       28            Private    Bachelors             13
# ...    ...                ...          ...            ...
# 32556   27            Private   Assoc-acdm             12
# 32557   40            Private      HS-grad              9
# 32558   58            Private      HS-grad              9
# 32559   22            Private      HS-grad              9
# 32560   52       Self-emp-inc      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
sns.relplot(x='capital_loss',y='capital_gain',hue='marital_status',data=df)

# %%
sns.catplot(x='age',y='marital_status',kind='box',hue='gender',data=df)

# %%
sns.catplot(x='age',y='marital_status',kind='bar',hue='gender',data=df)

# %%
sns.catplot(x='age',y='marital_status',kind='violin',hue='gender',data=df)

# %%
sns.catplot(x='marital_status',kind='count',hue='gender',data=df)
